# %% [markdown]
# ## 配对交易策略 Pair Trading

# %%
import pandas as pd
import numpy as np
import tushare as ts
import seaborn
# %matplotlib inline
from matplotlib import pyplot as plt
stocks_pair = ['600199', '600702']

# %% [markdown]
# ### 1. 数据准备 & 回测准备

# %%
data1 = ts.get_k_data('600199', '2013-06-01', '2014-12-31')[['date','close']]
data1.head()
# Out:
#            date   close
# 96   2013-06-03  15.480
# 97   2013-06-04  14.856
# 98   2013-06-05  15.019
# 99   2013-06-06  14.645
# 100  2013-06-07  14.222

# %%
data2 = ts.get_k_data('600702', '2013-06-01', '2014-12-31')['close']
data2.head()
# Out:
# 96     17.320
# 97     16.930
# 98     17.144
# 99     16.843
# 100    16.609
# Name: close, dtype: float64

# %%
data = pd.concat([data1, data2], axis=1)                 #拼接，把两张表格的数据拼接起来；
data.head()
# Out:
#            date   close   close
# 96   2013-06-03  15.480  17.320
# 97   2013-06-04  14.856  16.930
# 98   2013-06-05  15.019  17.144
# 99   2013-06-06  14.645  16.843
# 100  2013-06-07  14.222  16.609

# %%
data.set_index('date',inplace = True)
data.columns = stocks_pair
data.head()
# Out:
#             600199  600702
# date
# 2013-06-03  15.480  17.320
# 2013-06-04  14.856  16.930
# 2013-06-05  15.019  17.144
# 2013-06-06  14.645  16.843
# 2013-06-07  14.222  16.609

# %%
data.plot(figsize= (8,6))

# %% [markdown]
# ### 2. 策略开发思路

# %%
# data['pair_ratio'] =data[stocks_pair[0]]/data[stocks_pair[1]]
# mean = data['pair_ratio'].mean()
# std = data['pair_ratio'].std()
# data['ratio_mean'] = mean
# data['ratio_ceiling'] = mean + std
# data['ratio_floor'] = mean - std

# %%
data['priceDelta']=data['600199']-data['600702']

# %%
data.head()
# Out:
#             600199  600702  priceDelta
# date
# 2013-06-03  15.480  17.320      -1.840
# 2013-06-04  14.856  16.930      -2.074
# 2013-06-05  15.019  17.144      -2.125
# 2013-06-06  14.645  16.843      -2.198
# 2013-06-07  14.222  16.609      -2.387

# %%
data['priceDelta'].plot(figsize= (8,6))
plt.ylabel('Spread')
plt.axhline(data['priceDelta'].mean())

# %%
data['zscore'] = (data['priceDelta'] - np.mean(data['priceDelta']))/np.std(data['priceDelta'])     #价差的标准化；

# %% [markdown]
# 若zscore>1.5,600199过高，short600199，long600702

# %%
data.head(20)
# Out:
#             600199  600702  priceDelta    zscore
# date
# 2013-06-03  15.480  17.320      -1.840  1.962060
# 2013-06-04  14.856  16.930      -2.074  1.745803
# 2013-06-05  15.019  17.144      -2.125  1.698670
# 2013-06-06  14.645  16.843      -2.198  1.631205
# 2013-06-07  14.222  16.609      -2.387  1.456536
# 2013-06-13  14.136  15.859      -1.723  2.070189
# 2013-06-14  14.309  15.966      -1.657  2.131184
# 2013-06-17  13.876  15.655      -1.779  2.018435
# 2013-06-18  13.944  15.996      -2.052  1.766135
# 2013-06-19  14.702  16.658      -1.956  1.854856
# 2013-06-20  14.347  16.025      -1.678  2.111776
# 2013-06-21  14.626  16.132      -1.506  2.270735
# 2013-06-24  13.828  15.256      -1.428  2.342820
# 2013-06-25  14.015  14.934      -0.919  2.813226
# 2013-06-26  13.838  14.594      -0.756  2.963867
# 2013-06-27  13.190  14.146      -0.956  2.779031
# 2013-06-28  13.259  14.302      -1.043  2.698628
# 2013-07-01  12.886  14.292      -1.406  2.363152
# 2013-07-02  13.416  15.723      -2.307  1.530470
# 2013-07-03  13.082  16.521      -3.439  0.484303

# %%
data[data['zscore'] < - 1.5].head()
# Out:
#             600199  600702  priceDelta    zscore
# date
# 2013-07-24  12.611  18.512      -5.901 -1.791018
# 2013-07-25  12.886  19.307      -6.421 -2.271590
# 2013-07-26  12.562  18.741      -6.179 -2.047939
# 2013-07-29  12.297  18.036      -5.739 -1.641302
# 2013-07-30  12.317  18.086      -5.769 -1.669027

# %%
len(data[data['zscore'] < - 1.5])
# Out:
# 30

# %%
data['position_1'] = np.where(data['zscore'] > 1.5, -1, np.nan)
data['position_1'] = np.where(data['zscore'] < -1.5, 1, data['position_1'])
data['position_1'] = np.where(abs(data['zscore']) < 0.5, 0, data['position_1'])

# %%
data.head(50)
# Out:
#             600199  600702  priceDelta    zscore  position_1
# date
# 2013-06-03  15.480  17.320      -1.840  1.962060        -1.0
# 2013-06-04  14.856  16.930      -2.074  1.745803        -1.0
# 2013-06-05  15.019  17.144      -2.125  1.698670        -1.0
# 2013-06-06  14.645  16.843      -2.198  1.631205        -1.0
# 2013-06-07  14.222  16.609      -2.387  1.456536         NaN
# 2013-06-13  14.136  15.859      -1.723  2.070189        -1.0
# 2013-06-14  14.309  15.966      -1.657  2.131184        -1.0
# 2013-06-17  13.876  15.655      -1.779  2.018435        -1.0
# 2013-06-18  13.944  15.996      -2.052  1.766135        -1.0
# 2013-06-19  14.702  16.658      -1.956  1.854856        -1.0
# 2013-06-20  14.347  16.025      -1.678  2.111776        -1.0
# 2013-06-21  14.626  16.132      -1.506  2.270735        -1.0
# 2013-06-24  13.828  15.256      -1.428  2.342820        -1.0
# 2013-06-25  14.015  14.934      -0.919  2.813226        -1.0
# 2013-06-26  13.838  14.594      -0.756  2.963867        -1.0
# 2013-06-27  13.190  14.146      -0.956  2.779031        -1.0
# 2013-06-28  13.259  14.302      -1.043  2.698628        -1.0
# 2013-07-01  12.886  14.292      -1.406  2.363152        -1.0
# 2013-07-02  13.416  15.723      -2.307  1.530470        -1.0
# 2013-07-03  13.082  16.521      -3.439  0.484303         0.0
# 2013-07-04  13.298  16.502      -3.204  0.701484         NaN
# 2013-07-05  13.347  17.261      -3.914  0.045319         0.0
# 2013-07-08  12.915  17.534      -4.619 -0.606225         NaN
# 2013-07-09  12.591  17.359      -4.768 -0.743927         NaN
# 2013-07-10  12.994  18.050      -5.056 -1.010090         NaN
# 2013-07-11  13.632  17.524      -3.892  0.065651         0.0
# 2013-07-12  13.151  16.745      -3.594  0.341055         0.0
# 2013-07-15  13.259  16.745      -3.486  0.440866         0.0
# 2013-07-16  13.465  17.738      -4.273 -0.286460         0.0
# 2013-07-17  13.112  16.979      -3.867  0.088755         0.0
# 2013-07-18  12.856  16.775      -3.919  0.040698         0.0
# 2013-07-19  12.513  16.755      -4.242 -0.257810         0.0
# 2013-07-22  12.474  17.440      -4.966 -0.926914         NaN
# 2013-07-23  12.739  17.788      -5.049 -1.003620         NaN
# 2013-07-24  12.611  18.512      -5.901 -1.791018         1.0
# 2013-07-25  12.886  19.307      -6.421 -2.271590         1.0
# 2013-07-26  12.562  18.741      -6.179 -2.047939         1.0
# 2013-07-29  12.297  18.036      -5.739 -1.641302         1.0
# 2013-07-30  12.317  18.086      -5.769 -1.669027         1.0
# 2013-07-31  12.160  17.877      -5.717 -1.620970         1.0
# 2013-08-01  12.356  17.947      -5.591 -1.504524         1.0
# 2013-08-02  12.376  18.016      -5.640 -1.549808         1.0
# 2013-08-05  12.484  17.857      -5.373 -1.303053         NaN
# 2013-08-06  12.670  17.877      -5.207 -1.149640         NaN
# 2013-08-07  12.621  17.520      -4.899 -0.864994         NaN
# 2013-08-08  12.513  17.321      -4.808 -0.780894         NaN
# 2013-08-09  12.542  16.974      -4.432 -0.433404         0.0
# 2013-08-12  13.121  17.887      -4.766 -0.742079         NaN
# 2013-08-13  13.210  17.798      -4.588 -0.577575         NaN
# 2013-08-14  13.092  17.629      -4.537 -0.530442         NaN

# %% [markdown]
# #### 产生交易信号

# %%
data['position_1'] = data['position_1'].fillna(method = 'ffill')   #向下填充

# %%
data['position_1'].plot(ylim=[-1.1, 1.1], figsize=(10, 6))

# %%
data['position_2'] = -np.sign(data['position_1'])

# %%
data.head(20)
# Out:
#             600199  600702  priceDelta    zscore  position_1  position_2
# date
# 2013-06-03  15.480  17.320      -1.840  1.962060        -1.0         1.0
# 2013-06-04  14.856  16.930      -2.074  1.745803        -1.0         1.0
# 2013-06-05  15.019  17.144      -2.125  1.698670        -1.0         1.0
# 2013-06-06  14.645  16.843      -2.198  1.631205        -1.0         1.0
# 2013-06-07  14.222  16.609      -2.387  1.456536        -1.0         1.0
# 2013-06-13  14.136  15.859      -1.723  2.070189        -1.0         1.0
# 2013-06-14  14.309  15.966      -1.657  2.131184        -1.0         1.0
# 2013-06-17  13.876  15.655      -1.779  2.018435        -1.0         1.0
# 2013-06-18  13.944  15.996      -2.052  1.766135        -1.0         1.0
# 2013-06-19  14.702  16.658      -1.956  1.854856        -1.0         1.0
# 2013-06-20  14.347  16.025      -1.678  2.111776        -1.0         1.0
# 2013-06-21  14.626  16.132      -1.506  2.270735        -1.0         1.0
# 2013-06-24  13.828  15.256      -1.428  2.342820        -1.0         1.0
# 2013-06-25  14.015  14.934      -0.919  2.813226        -1.0         1.0
# 2013-06-26  13.838  14.594      -0.756  2.963867        -1.0         1.0
# 2013-06-27  13.190  14.146      -0.956  2.779031        -1.0         1.0
# 2013-06-28  13.259  14.302      -1.043  2.698628        -1.0         1.0
# 2013-07-01  12.886  14.292      -1.406  2.363152        -1.0         1.0
# 2013-07-02  13.416  15.723      -2.307  1.530470        -1.0         1.0
# 2013-07-03  13.082  16.521      -3.439  0.484303         0.0        -0.0

# %%
data['position_2'].plot(ylim=[-1.1, 1.1], figsize=(10, 6))

# %% [markdown]
# ### 3. 计算策略年化收益并可视化

# %%
data['returns_1'] = np.log(data['600199'] / data['600199'].shift(1))

# %%
data['returns_2'] = np.log(data['600702'] / data['600702'].shift(1))

# %%
data.head(20)
# Out:
#             600199  600702  priceDelta    zscore  position_1  position_2  \
# date
# 2013-06-03  15.480  17.320      -1.840  1.962060        -1.0         1.0
# 2013-06-04  14.856  16.930      -2.074  1.745803        -1.0         1.0
# 2013-06-05  15.019  17.144      -2.125  1.698670        -1.0         1.0
# 2013-06-06  14.645  16.843      -2.198  1.631205        -1.0         1.0
# 2013-06-07  14.222  16.609      -2.387  1.456536        -1.0         1.0
# 2013-06-13  14.136  15.859      -1.723  2.070189        -1.0         1.0
# 2013-06-14  14.309  15.966      -1.657  2.131184        -1.0         1.0
# 2013-06-17  13.876  15.655      -1.779  2.018435        -1.0         1.0
# 2013-06-18  13.944  15.996      -2.052  1.766135        -1.0         1.0
# 2013-06-19  14.702  16.658      -1.956  1.854856        -1.0         1.0
# 2013-06-20  14.347  16.025      -1.678  2.111776        -1.0         1.0
# 2013-06-21  14.626  16.132      -1.506  2.270735        -1.0         1.0
# 2013-06-24  13.828  15.256      -1.428  2.342820        -1.0         1.0
# 2013-06-25  14.015  14.934      -0.919  2.813226        -1.0         1.0
# 2013-06-26  13.838  14.594      -0.756  2.963867        -1.0         1.0
# 2013-06-27  13.190  14.146      -0.956  2.779031        -1.0         1.0
# 2013-06-28  13.259  14.302      -1.043  2.698628        -1.0         1.0
# 2013-07-01  12.886  14.292      -1.406  2.363152        -1.0         1.0
# 2013-07-02  13.416  15.723      -2.307  1.530470        -1.0         1.0
# 2013-07-03  13.082  16.521      -3.439  0.484303         0.0        -0.0
#
#             returns_1  returns_2
# date
# 2013-06-03        NaN        NaN
# 2013-06-04  -0.041145  -0.022775
# 2013-06-05   0.010912   0.012561
# 2013-06-06  -0.025217  -0.017713
# 2013-06-07  -0.029309  -0.013990
# 2013-06-13  -0.006065  -0.046208
# 2013-06-14   0.012164   0.006724
# 2013-06-17  -0.030728  -0.019671
# 2013-06-18   0.004889   0.021548
# 2013-06-19   0.052934   0.040552
# 2013-06-20  -0.024443  -0.038741
# 2013-06-21   0.019260   0.006655
# 2013-06-24  -0.056105  -0.055832
# 2013-06-25   0.013433  -0.021332
# 2013-06-26  -0.012710  -0.023030
# 2013-06-27  -0.047959  -0.031179
# 2013-06-28   0.005218   0.010967
# 2013-07-01  -0.028535  -0.000699
# 2013-07-02   0.040307   0.095425
# 2013-07-03  -0.025211   0.049508

# %%
data['strategy'] = 0.5*(data['position_1'].shift(1) * data['returns_1'])+0.5*(data['position_2'].shift(1) * data['returns_2']) #用昨天的position
#今天的return

# %%
data[['returns_1','returns_2','strategy']].dropna().cumsum().apply(np.exp).plot(figsize=(10, 6))
