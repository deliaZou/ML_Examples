# %% [markdown]
# ### 爬取周星驰相关的100位演员关系网络

# %%
import requests
import json
#周星驰演员id=1048026
actor_id = '1048026'
access_key = '0df993c66c0c636e29ecbb5344252a4a' 
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'}
res = requests.get(f'http://api.douban.com/v2/movie/celebrity/{actor_id}?apikey={access_key}',headers=headers)
json.loads(res.content.decode('utf-8'))
# Out:
# {'website': '',
#  'mobile_url': 'https://movie.douban.com/celebrity/1048026/mobile',
#  'aka_en': ['Sing-Chi Chow (本名)', 'Sing Jai (昵称)'],
#  'name': '周星驰',
#  'works': [{'roles': ['演员'],
#    'subject': {'rating': {'max': 10,
#      'average': 9.2,
#      'details': {'1': 1948.0,
#       '3': 45854.0,
#       '2': 3542.0,
#       '5': 517327.0,
#       '4': 202411.0},
#      'stars': '45',
#      'min': 0},
#     'genres': ['喜剧', '爱情', '奇幻'],
#     'title': '大话西游之大圣娶亲',
#     'casts': [{'avatars': {'small': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg',
#        'large': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg',
#        'medium': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg'},
#       'name_en': 'Stephen Chow',
#       'name': '周星驰',
#       'alt': 'https://movie.douban.com/celebrity/1048026/',
#       'id': '1048026'},
#      {'avatars': {'small': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p45481.jpg',
#        'large': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p45481.jpg',
#        'medium': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p45481.jpg'},
#       'name_en': 'Man Tat Ng',
#       'name': '吴孟达',
#       'alt': 'https://movie.douban.com/celebrity/1016771/',
#       'id': '1016771'},
#      {'avatars': {'small': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p49237.jpg',
#        'large': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p49237.jpg',
#        'medium': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p49237.jpg'},
#       'name_en': 'Athena Chu',
#       'name': '朱茵',
#       'alt': 'https://movie.douban.com/celebrity/1041734/',
#       'id': '1041734'}],
#     'durations': ['95分钟', '110分钟(重映版)'],
#     'collect_count': 1464260,
#     'mainland_pubdate': '2014-10-24',
#     'has_video': True,
#     'original_title': '西遊記大結局之仙履奇緣',
#     'subtype': 'movie',
#     'directors': [{'avatars': {'small': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p45374.jpg',
#        'large': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p45374.jpg',
#        'medium': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p45374.jpg'},
#       'name_en': 'Jeffrey Lau',
#       'name': '刘镇伟',
#       'alt': 'https://movie.douban.com/celebrity/1274431/',
#       'id': '1274431'}],
#     'pubdates': ['1995-02-04(中国香港)', '2014-10-24(中国大陆)', '2017-04-13(中国大陆重映)'],
#     'year': '1995',
#     'images': {'small': 'http://img9.doubanio.com/view/photo/s_ratio_poster/public/p2455050536.jpg',
#      'large': 'http://img9.doubanio.com/view/photo/s_ratio_poster/public/p2455050536.jpg',
#      'medium': 'http://img9.doubanio.com/view/photo/s_ratio_poster/public/p2455050536.jpg'},
#     'alt': 'https://movie.douban.com/subject/1292213/',
#     'id': '1292213'}},
#   {'roles': ['演员'],
#    'subject': {'rating': {'max': 10,
#      'average': 9.1,
#      'details': {'1': 455.0,
#       '3': 2548.0,
#       '2': 271.0,
#       '5': 27656.0,
#       '4': 11369.0},
#      'stars': '45',
#      'min': 0},
#     'genres': ['剧情', '动作', '武侠'],
#     'title': '射雕英雄传',
#     'casts': [{'avatars': {'small': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p2365.jpg',
#        'large': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p2365.jpg',
#        'medium': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p2365.jpg'},
#       'name_en': 'Felix Wong',
#       'name': '黄日华',
#       'alt': 'https://movie.douban.com/celebrity/1050735/',
#       'id': '1050735'},
#      {'avatars': {'small': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p6690.jpg',
#        'large': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p6690.jpg',
#        'medium': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p6690.jpg'},
#       'name_en': 'Barbara Yung',
#       'name': '翁美玲',
#       'alt': 'https://movie.douban.com/celebrity/1125851/',
#       'id': '1125851'},
#      {'avatars': {'small': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p2247.jpg',
#        'large': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p2247.jpg',
#        'medium': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p2247.jpg'},
#       'name_en': 'Kiu Wai Miu',
#       'name': '苗侨伟',
#       'alt': 'https://movie.douban.com/celebrity/1115415/',
#       'id': '1115415'}],
#     'durations': ['42分钟'],
#     'collect_count': 69589,
#     'mainland_pubdate': '',
#     'has_video': False,
#     'original_title': '射鵰英雄傳',
#     'subtype': 'tv',
#     'directors': [{'avatars': {'small': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p3416.jpg',
#        'large': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p3416.jpg',
#        'medium': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p3416.jpg'},
#       'name_en': 'Tian-lin Wang',
#       'name': '王天林',
#       'alt': 'https://movie.douban.com/celebrity/1041074/',
#       'id': '1041074'},
#      {'avatars': {'small': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p851.jpg',
#        'large': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p851.jpg',
#        'medium': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p851.jpg'},
#       'name_en': 'Johnnie To',
#       'name': '杜琪峰',
#       'alt': 'https://movie.douban.com/celebrity/1160186/',
#       'id': '1160186'}],
#     'pubdates': ['1983-05-24(中国香港)'],
#     'year': '1983',
#     'images': {'small': 'http://img1.doubanio.com/view/photo/s_ratio_poster/public/p2538637598.jpg',
#      'large': 'http://img1.doubanio.com/view/photo/s_ratio_poster/public/p2538637598.jpg',
#      'medium': 'http://img1.doubanio.com/view/photo/s_ratio_poster/public/p2538637598.jpg'},
#     'alt': 'https://movie.douban.com/subject/1478186/',
#     'id': '1478186'}},
#   {'roles': ['演员'],
#    'subject': {'rating': {'max': 10,
#      'average': 9.0,
#      'details': {'1': 1361.0,
#       '3': 50460.0,
#       '2': 3493.0,
#       '5': 369554.0,
#       '4': 207274.0},
#      'stars': '45',
#      'min': 0},
#     'genres': ['喜剧', '爱情', '奇幻'],
#     'title': '大话西游之月光宝盒',
#     'casts': [{'avatars': {'small': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg',
#        'large': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg',
#        'medium': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg'},
#       'name_en': 'Stephen Chow',
#       'name': '周星驰',
#       'alt': 'https://movie.douban.com/celebrity/1048026/',
#       'id': '1048026'},
#      {'avatars': {'small': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p45481.jpg',
#        'large': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p45481.jpg',
#        'medium': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p45481.jpg'},
#       'name_en': 'Man Tat Ng',
#       'name': '吴孟达',
#       'alt': 'https://movie.douban.com/celebrity/1016771/',
#       'id': '1016771'},
#      {'avatars': {'small': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p1566882903.33.jpg',
#        'large': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p1566882903.33.jpg',
#        'medium': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p1566882903.33.jpg'},
#       'name_en': 'Kar-Ying Law',
#       'name': '罗家英',
#       'alt': 'https://movie.douban.com/celebrity/1108968/',
#       'id': '1108968'}],
#     'durations': ['87分钟'],
#     'collect_count': 1282453,
#     'mainland_pubdate': '2014-10-24',
#     'has_video': True,
#     'original_title': '西遊記第壹佰零壹回之月光寶盒',
#     'subtype': 'movie',
#     'directors': [{'avatars': {'small': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p45374.jpg',
#        'large': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p45374.jpg',
#        'medium': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p45374.jpg'},
#       'name_en': 'Jeffrey Lau',
#       'name': '刘镇伟',
#       'alt': 'https://movie.douban.com/celebrity/1274431/',
#       'id': '1274431'}],
#     'pubdates': ['1995-01-21(中国香港)', '2014-10-24(中国大陆)'],
#     'year': '1995',
#     'images': {'small': 'http://img3.doubanio.com/view/photo/s_ratio_poster/public/p2561721372.jpg',
#      'large': 'http://img3.doubanio.com/view/photo/s_ratio_poster/public/p2561721372.jpg',
#      'medium': 'http://img3.doubanio.com/view/photo/s_ratio_poster/public/p2561721372.jpg'},
#     'alt': 'https://movie.douban.com/subject/1299398/',
#     'id': '1299398'}},
#   {'roles': ['演员', '导演', '编剧'],
#    'subject': {'rating': {'max': 10,
#      'average': 8.7,
#      'details': {'1': 644.0,
#       '3': 52471.0,
#       '2': 3337.0,
#       '5': 230756.0,
#       '4': 193491.0},
#      'stars': '45',
#      'min': 0},
#     'genres': ['喜剧', '剧情', '爱情'],
#     'title': '喜剧之王',
#     'casts': [{'avatars': {'small': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg',
#        'large': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg',
#        'medium': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg'},
#       'name_en': 'Stephen Chow',
#       'name': '周星驰',
#       'alt': 'https://movie.douban.com/celebrity/1048026/',
#       'id': '1048026'},
#      {'avatars': {'small': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p1394446025.33.jpg',
#        'large': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p1394446025.33.jpg',
#        'medium': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p1394446025.33.jpg'},
#       'name_en': 'Cecilia Cheung',
#       'name': '张柏芝',
#       'alt': 'https://movie.douban.com/celebrity/1003495/',
#       'id': '1003495'},
#      {'avatars': {'small': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p979.jpg',
#        'large': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p979.jpg',
#        'medium': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p979.jpg'},
#       'name_en': 'Karen Mok',
#       'name': '莫文蔚',
#       'alt': 'https://movie.douban.com/celebrity/1018248/',
#       'id': '1018248'}],
#     'durations': ['85分钟', '89分钟(DVD)'],
#     'collect_count': 964018,
#     'mainland_pubdate': '',
#     'has_video': True,
#     'original_title': '喜劇之王',
#     'subtype': 'movie',
#     'directors': [{'avatars': {'small': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg',
#        'large': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg',
#        'medium': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg'},
#       'name_en': 'Stephen Chow',
#       'name': '周星驰',
#       'alt': 'https://movie.douban.com/celebrity/1048026/',
#       'id': '1048026'},
#      {'avatars': {'small': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p51748.jpg',
#        'large': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p51748.jpg',
#        'medium': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p51748.jpg'},
#       'name_en': 'Lik-Chi Lee',
#       'name': '李力持',
#       'alt': 'https://movie.douban.com/celebrity/1274246/',
#       'id': '1274246'}],
#     'pubdates': ['1999-02-13(中国香港)'],
#     'year': '1999',
#     'images': {'small': 'http://img9.doubanio.com/view/photo/s_ratio_poster/public/p1043597424.jpg',
#      'large': 'http://img9.doubanio.com/view/photo/s_ratio_poster/public/p1043597424.jpg',
#      'medium': 'http://img9.doubanio.com/view/photo/s_ratio_poster/public/p1043597424.jpg'},
#     'alt': 'https://movie.douban.com/subject/1302425/',
#     'id': '1302425'}},
#   {'roles': ['演员'],
#    'subject': {'rating': {'max': 10,
#      'average': 8.6,
#      'details': {'1': 714.0,
#       '3': 64198.0,
#       '2': 3599.0,
#       '5': 224299.0,
#       '4': 226920.0},
#      'stars': '45',
#      'min': 0},
#     'genres': ['喜剧', '爱情', '古装'],
#     'title': '唐伯虎点秋香',
#     'casts': [{'avatars': {'small': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg',
#        'large': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg',
#        'medium': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg'},
#       'name_en': 'Stephen Chow',
#       'name': '周星驰',
#       'alt': 'https://movie.douban.com/celebrity/1048026/',
#       'id': '1048026'},
#      {'avatars': {'small': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p1399268395.47.jpg',
#        'large': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p1399268395.47.jpg',
#        'medium': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p1399268395.47.jpg'},
#       'name_en': 'Li Gong',
#       'name': '巩俐',
#       'alt': 'https://movie.douban.com/celebrity/1035641/',
#       'id': '1035641'},
#      {'avatars': {'small': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p796.jpg',
#        'large': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p796.jpg',
#        'medium': 'http://img9.doubanio.com/view/celebrity/s_ratio_celebrity/public/p796.jpg'},
#       'name_en': 'Pak-cheung Chan',
#       'name': '陈百祥',
#       'alt': 'https://movie.douban.com/celebrity/1070608/',
#       'id': '1070608'}],
#     'durations': ['102 分钟'],
#     'collect_count': 1105469,
#     'mainland_pubdate': '',
#     'has_video': True,
#     'original_title': '唐伯虎點秋香',
#     'subtype': 'movie',
#     'directors': [{'avatars': {'small': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p51748.jpg',
#        'large': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p51748.jpg',
#        'medium': 'http://img1.doubanio.com/view/celebrity/s_ratio_celebrity/public/p51748.jpg'},
#       'name_en': 'Lik-Chi Lee',
#       'name': '李力持',
#       'alt': 'https://movie.douban.com/celebrity/1274246/',
#       'id': '1274246'}],
#     'pubdates': ['1993-07-01(中国香港)'],
#     'year': '1993',
#     'images': {'small': 'http://img3.doubanio.com/view/photo/s_ratio_poster/public/p1946455272.jpg',
#      'large': 'http://img3.doubanio.com/view/photo/s_ratio_poster/public/p1946455272.jpg',
#      'medium': 'http://img3.doubanio.com/view/photo/s_ratio_poster/public/p1946455272.jpg'},
#     'alt': 'https://movie.douban.com/subject/1306249/',
#     'id': '1306249'}}],
#  'name_en': 'Stephen Chow',
#  'gender': '男',
#  'professions': ['', '', '编剧', '导演', '制片人'],
#  'avatars': {'small': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg',
#   'large': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg',
#   'medium': 'http://img3.doubanio.com/view/celebrity/s_ratio_celebrity/public/p47421.jpg'},
#  'summary': '周星驰（1962年6月22日— ），生于香港，英文名Stephen Chow，著名演员，兼导演、编剧、电影监制以及电影制作人。曾主演《九品芝麻官》、《长江七号》等多部喜剧影片。捧红过张柏芝、张雨绮等影星。曾获1998年国际杰人会港澳杰人之星奖。其与成龙和周润发并称“双周一成”，意为香港电影票房的保证。\r\n',
#  'photos': [{'thumb': 'https://img9.doubanio.com/view/photo/m/public/p2154939985.jpg',
#    'image': 'https://img9.doubanio.com/view/photo/l/public/p2154939985.jpg',
#    'cover': 'https://img9.doubanio.com/view/photo/sqs/public/p2154939985.jpg',
#    'alt': 'https://movie.douban.com/celebrity/1048026/photo/2154939985/',
#    'id': '2154939985',
#    'icon': 'https://img9.doubanio.com/view/photo/s/public/p2154939985.jpg'},
#   {'thumb': 'https://img1.doubanio.com/view/photo/m/public/p1635406128.jpg',
#    'image': 'https://img1.doubanio.com/view/photo/l/public/p1635406128.jpg',
#    'cover': 'https://img1.doubanio.com/view/photo/sqs/public/p1635406128.jpg',
#    'alt': 'https://movie.douban.com/celebrity/1048026/photo/1635406128/',
#    'id': '1635406128',
#    'icon': 'https://img1.doubanio.com/view/photo/s/public/p1635406128.jpg'},
#   {'thumb': 'https://img1.doubanio.com/view/photo/m/public/p1545600068.jpg',
#    'image': 'https://img1.doubanio.com/view/photo/l/public/p1545600068.jpg',
#    'cover': 'https://img1.doubanio.com/view/photo/sqs/public/p1545600068.jpg',
#    'alt': 'https://movie.douban.com/celebrity/1048026/photo/1545600068/',
#    'id': '1545600068',
#    'icon': 'https://img1.doubanio.com/view/photo/s/public/p1545600068.jpg'},
#   {'thumb': 'https://img9.doubanio.com/view/photo/m/public/p1871344945.jpg',
#    'image': 'https://img9.doubanio.com/view/photo/l/public/p1871344945.jpg',
#    'cover': 'https://img9.doubanio.com/view/photo/sqs/public/p1871344945.jpg',
#    'alt': 'https://movie.douban.com/celebrity/1048026/photo/1871344945/',
#    'id': '1871344945',
#    'icon': 'https://img9.doubanio.com/view/photo/s/public/p1871344945.jpg'},
#   {'thumb': 'https://img3.doubanio.com/view/photo/m/public/p2564990993.jpg',
#    'image': 'https://img3.doubanio.com/view/photo/l/public/p2564990993.jpg',
#    'cover': 'https://img3.doubanio.com/view/photo/sqs/public/p2564990993.jpg',
#    'alt': 'https://movie.douban.com/celebrity/1048026/photo/2564990993/',
#    'id': '2564990993',
#    'icon': 'https://img3.doubanio.com/view/photo/s/public/p2564990993.jpg'},
#   {'thumb': 'https://img1.doubanio.com/view/photo/m/public/p1799134228.jpg',
#    'image': 'https://img1.doubanio.com/view/photo/l/public/p1799134228.jpg',
#    'cover': 'https://img1.doubanio.com/view/photo/sqs/public/p1799134228.jpg',
#    'alt': 'https://movie.douban.com/celebrity/1048026/photo/1799134228/',
#    'id': '1799134228',
#    'icon': 'https://img1.doubanio.com/view/photo/s/public/p1799134228.jpg'},
#   {'thumb': 'https://img3.doubanio.com/view/photo/m/public/p1884583560.jpg',
#    'image': 'https://img3.doubanio.com/view/photo/l/public/p1884583560.jpg',
#    'cover': 'https://img3.doubanio.com/view/photo/sqs/public/p1884583560.jpg',
#    'alt': 'https://movie.douban.com/celebrity/1048026/photo/1884583560/',
#    'id': '1884583560',
#    'icon': 'https://img3.doubanio.com/view/photo/s/public/p1884583560.jpg'},
#   {'thumb': 'https://img3.doubanio.com/view/photo/m/public/p1826590363.jpg',
#    'image': 'https://img3.doubanio.com/view/photo/l/public/p1826590363.jpg',
#    'cover': 'https://img3.doubanio.com/view/photo/sqs/public/p1826590363.jpg',
#    'alt': 'https://movie.douban.com/celebrity/1048026/photo/1826590363/',
#    'id': '1826590363',
#    'icon': 'https://img3.doubanio.com/view/photo/s/public/p1826590363.jpg'},
#   {'thumb': 'https://img1.doubanio.com/view/photo/m/public/p2210525717.jpg',
#    'image': 'https://img1.doubanio.com/view/photo/l/public/p2210525717.jpg',
#    'cover': 'https://img1.doubanio.com/view/photo/sqs/public/p2210525717.jpg',
#    'alt': 'https://movie.douban.com/celebrity/1048026/photo/2210525717/',
#    'id': '2210525717',
#    'icon': 'https://img1.doubanio.com/view/photo/s/public/p2210525717.jpg'},
#   {'thumb': 'https://img9.doubanio.com/view/photo/m/public/p643014025.jpg',
#    'image': 'https://img9.doubanio.com/view/photo/l/public/p643014025.jpg',
#    'cover': 'https://img9.doubanio.com/view/photo/sqs/public/p643014025.jpg',
#    'alt': 'https://movie.douban.com/celebrity/1048026/photo/643014025/',
#    'id': '643014025',
#    'icon': 'https://img9.doubanio.com/view/photo/s/public/p643014025.jpg'}],
#  'birthday': '1962-06-22',
#  'aka': ['星爷(昵称)', '周星星(昵称)'],
#  'alt': 'https://movie.douban.com/celebrity/1048026/',
#  'born_place': '中国香港',
#  'constellation': '巨蟹座',
#  'id': '1048026'}

# %%
#批量获取接口数据的方法
def get(url,headers):
    while True:
        try:
            res = requests.get(url,headers = headers, timeout = 5)
            return json.loads(res.content.decode('utf-8'))
        except requests.exceptions.Timeout:
            time.sleep(1)

# %%
import queue
import os
import requests
import json
access_key = '0df993c66c0c636e29ecbb5344252a4a'  # api key
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'}
# 演员队列初始为周星驰 id
actorQ = queue.Queue()
actorQ.put('1048026')#申请获得互斥锁，获得后，如果队列未满，则向队列中添加数据，并通知notify其它阻塞的某个线程，唤醒等待获取require互斥锁。如果队列已满，则会wait等待。最后处理完成后释放互斥锁。

total = 100
# 创建文件夹方便整理数据
if not os.path.exists('actors'):
    os.mkdir('actors')

while not actorQ.empty():
    actor_id = actorQ.get() #从队列中获取任务，并且从队列中移除此任务。
    actor_path = os.path.join('actors', str(actor_id)+'.json')
    # 如果已爬取则从本地读取
    if os.path.exists(actor_path):
        # 读取文件
        with open(actor_path,encoding = 'utf-8') as f:
            json_content = json.load(f)
    # 否则爬取数据
    else:
        json_content = get(f'http://api.douban.com/v2/movie/celebrity/{actor_id}?apikey={access_key}',headers)
        # 爬完后写入本地
        with open(actor_path, 'w',encoding = 'utf-8') as f:
            f.write(json.dumps(json_content, indent=4, ensure_ascii=False))

    # 遍历该演员的电影的其他演员，并将 id 加入 actorQ 重新遍历
    for movie in json_content['works']:
        for x in movie['subject']['casts']:
            # 如果没有该演员的 id 则跳过
            if x['id'] == None:
                continue
            actorQ.put(x['id'])
    if len(os.listdir('actors')) > total:
        print('爬取完毕')
        break
# Out:
# 爬取完毕

# %%
#将上面得到的 100 位演员的信息合并为一个 JSON 文件
actors = {}
for json_file in tqdm_notebook(os.listdir('actors')):
    json_file_path = os.path.join('actors', json_file)
    with open(json_file_path,encoding = 'utf-8') as f:
        json_content = json.load(f)
        actors[json_content['id']] = json_content
# 写入文件
with open('actors.json', 'w',encoding = 'utf-8') as f:
    f.write(json.dumps({'actors': actors}, indent=4, ensure_ascii=False))

# %% [markdown]
# ### 绘图分析周星驰相关的 100 位演员关系网络

# %%
# 加载演员数据
with open('actors.json',encoding = 'utf-8') as f:
    actors_data = json.load(f)['actors']

# %%
import itertools
# 有过合作的演员的组合
has_cooperated_actors = []
# 所有演员的名字
all_names = []
# 统计演员一起出现的电影
for actor_id in actors_data:
    # 演员演过的电影
    movies = actors_data[actor_id]['works']
    for movie in movies:
        # 获取电影的主演的 id
        # 有一些演员的ID为空，大部分都是一些名气不大的演员，所以影响不大
        movie_actors = [actor['name'] for actor in movie['subject']
                        ['casts'] if actor['id'] in actors_data.keys()]
        all_names += movie_actors
        has_cooperated_actors += list(itertools.combinations(movie_actors, 2))
has_cooperated_actors = list(set(has_cooperated_actors))
all_names = list(set(all_names))
has_cooperated_actors
# Out:
# [('温兆伦', '洪欣'),
#  ('张柏芝', '陈奕迅'),
#  ('周润发', '刘嘉玲'),
#  ('巩俐', '陈百祥'),
#  ('黄杏秀', '汤镇业'),
#  ('张国荣', '梁朝伟'),
#  ('周润发', '吕良伟'),
#  ('黄日华', '陈秀雯'),
#  ('吴孟达', '张敏'),
#  ('周润发', '吴孟达'),
#  ('周润发', '赵雅芝'),
#  ('江华', '汤镇业'),
#  ('严屹宽', '富大龙'),
#  ('周星驰', '巩俐'),
#  ('朱茵', '林倩萍'),
#  ('张柏芝', '卢巧音'),
#  ('姜文', '巩俐'),
#  ('郑皓原', '刘筱筱'),
#  ('周星驰', '林青霞'),
#  ('钟汉良', '刘筱筱'),
#  ('苗侨伟', '石修'),
#  ('巩俐', '滕汝骏'),
#  ('潘迎紫', '顾冠忠'),
#  ('刘德华', '林子祥'),
#  ('梁朝伟', '章子怡'),
#  ('金城武', '梁朝伟'),
#  ('佘诗曼', '薛家燕'),
#  ('陈奕迅', '卢巧音'),
#  ('陈道明', '秦岚'),
#  ('张国荣', '莫文蔚'),
#  ('萧芳芳', '乔宏'),
#  ('周星驰', '朱茵'),
#  ('尹扬明', '陈秀雯'),
#  ('张国荣', '邱淑贞'),
#  ('万梓良', '吕良伟'),
#  ('张智霖', '郭可盈'),
#  ('黄日华', '江华'),
#  ('巩俐', '姜武'),
#  ('朱茵', '魏骏杰'),
#  ('洪欣', '蔡少芬'),
#  ('郑丹瑞', '周秀兰'),
#  ('袁咏仪', '刘嘉玲'),
#  ('葛优', '浅野忠信'),
#  ('刘筱筱', '屈菁菁'),
#  ('黎明', '温兆伦'),
#  ('张国荣', '巩俐'),
#  ('孙俪', '陈建斌'),
#  ('温兆伦', '刘嘉玲'),
#  ('袁咏仪', '张国荣'),
#  ('张国荣', '张柏芝'),
#  ('周星驰', '吴孟达'),
#  ('周润发', '钟楚红'),
#  ('乔宏', '罗家英'),
#  ('萧芳芳', '李嘉欣'),
#  ('严屹宽', '张翰'),
#  ('张国立', '张涵予'),
#  ('金城武', '梁咏琪'),
#  ('陈建斌', '蔡少芬'),
#  ('李嘉欣', '金城武'),
#  ('张国荣', '钟楚红'),
#  ('萧芳芳', '罗家英'),
#  ('张晓龙', '刘筱筱'),
#  ('任达华', '温兆伦'),
#  ('张国立', '蒋雯丽'),
#  ('洪欣', '魏骏杰'),
#  ('李影', '郑秀文'),
#  ('姜文', '滕汝骏'),
#  ('张国荣', '刘嘉玲'),
#  ('钟汉良', '杨蕊'),
#  ('林青霞', '张国荣'),
#  ('姜文', '葛优'),
#  ('梁朝伟', '林青霞'),
#  ('佘诗曼', '林峯'),
#  ('温兆伦', '罗嘉良'),
#  ('萧芳芳', '袁咏仪'),
#  ('张国荣', '林青霞'),
#  ('温兆伦', '蔡少芬'),
#  ('苗侨伟', '任达华'),
#  ('陈浩民', '樊少皇'),
#  ('万梓良', '陈秀雯'),
#  ('周星驰', '张柏芝'),
#  ('黄日华', '伍咏薇'),
#  ('张国荣', '郑丹瑞'),
#  ('郭可盈', '张延'),
#  ('黄杏秀', '杨盼盼'),
#  ('陈秀雯', '张国荣'),
#  ('钟汉良', '张晓龙'),
#  ('赵雅芝', '吴孟达'),
#  ('朱茵', '罗嘉良'),
#  ('巩俐', '何赛飞'),
#  ('张卫健', '张国立'),
#  ('马精武', '何赛飞'),
#  ('袁咏仪', '罗家英'),
#  ('张卫健', '陈法蓉'),
#  ('张丰毅', '巩俐'),
#  ('章子怡', '浅野忠信'),
#  ('张国荣', '张丰毅'),
#  ('周润发', '章子怡'),
#  ('陶大宇', '张延'),
#  ('张涵予', '刘宇桥'),
#  ('黎明', '李嘉欣'),
#  ('富大龙', '张翰'),
#  ('陈道明', '何润东'),
#  ('周星驰', '莫文蔚'),
#  ('朱茵', '洪欣'),
#  ('蒋雯丽', '沈傲君'),
#  ('周星驰', '邱淑贞'),
#  ('吴孟达', '朱茵'),
#  ('李幼斌', '于小慧'),
#  ('万梓良', '陈法蓉'),
#  ('梁朝伟', '苗侨伟'),
#  ('金城武', '莫文蔚'),
#  ('黄日华', '任达华'),
#  ('陈秀雯', '陶大宇'),
#  ('周润发', '任达华'),
#  ('邱淑贞', '林青霞'),
#  ('梁朝伟', '吴岱融'),
#  ('吕良伟', '刘宇桥'),
#  ('黎明', '吴孟达'),
#  ('苗侨伟', '刘丹'),
#  ('姜文', '周润发'),
#  ('万梓良', '张卫健'),
#  ('钟汉良', '李立群'),
#  ('周星驰', '赵薇'),
#  ('汤镇业', '杨盼盼'),
#  ('刘嘉玲', '吴孟达'),
#  ('于小慧', '白凡'),
#  ('黄日华', '尹扬明'),
#  ('秦岚', '佘诗曼'),
#  ('张国荣', '周秀兰'),
#  ('黄日华', '苗侨伟'),
#  ('梁朝伟', '黎明'),
#  ('梁朝伟', '刘德华'),
#  ('孙俪', '蔡少芬'),
#  ('苗侨伟', '顾冠忠'),
#  ('周星驰', '张敏'),
#  ('吴孟达', '罗家英'),
#  ('罗嘉良', '张智霖'),
#  ('张柏芝', '莫文蔚'),
#  ('黄日华', '刘嘉玲'),
#  ('郑秀文', '林子祥'),
#  ('葛优', '巩俐'),
#  ('梁朝伟', '刘嘉玲'),
#  ('黄日华', '樊少皇'),
#  ('李立群', '杨蕊'),
#  ('张智霖', '佘诗曼'),
#  ('葛优', '章子怡'),
#  ('潘迎紫', '苗侨伟'),
#  ('翁美玲', '苗侨伟'),
#  ('陈汉玮', '朱茵'),
#  ('葛优', '姜武'),
#  ('黄日华', '石修'),
#  ('梁朝伟', '张国荣'),
#  ('张智霖', '朱茵'),
#  ('汤镇业', '黄日华'),
#  ('黎明', '金城武'),
#  ('梁咏琪', '莫文蔚'),
#  ('赵雅芝', '吕良伟'),
#  ('张智霖', '薛家燕'),
#  ('赵薇', '吴孟达'),
#  ('李幼斌', '白凡'),
#  ('张国立', '沈傲君'),
#  ('魏骏杰', '郑秀文'),
#  ('李影', '魏骏杰'),
#  ('梁朝伟', '邱淑贞'),
#  ('陶大宇', '郭可盈'),
#  ('郑皓原', '屈菁菁'),
#  ('巩俐', '马精武'),
#  ('周星驰', '罗家英'),
#  ('黄日华', '陈浩民'),
#  ('张涵予', '吕良伟'),
#  ('刘德华', '郑秀文'),
#  ('苗侨伟', '佘诗曼'),
#  ('万梓良', '张国荣'),
#  ('苗侨伟', '翁美玲'),
#  ('林青霞', '梁朝伟'),
#  ('邱淑贞', '张柏芝'),
#  ('张智霖', '钟汉良'),
#  ('周星驰', '袁咏仪'),
#  ('苗侨伟', '林峯'),
#  ('何润东', '秦岚'),
#  ('江华', '伍咏薇'),
#  ('刘德华', '梁朝伟'),
#  ('刘德华', '黎明'),
#  ('葛优', '周润发'),
#  ('翁美玲', '刘丹'),
#  ('张智霖', '罗嘉良'),
#  ('陈汉玮', '林倩萍'),
#  ('苗侨伟', '吴岱融'),
#  ('周润发', '刘德华'),
#  ('林青霞', '金城武'),
#  ('周星驰', '陈百祥'),
#  ('钟楚红', '林青霞'),
#  ('黄日华', '温兆伦'),
#  ('翁美玲', '任达华'),
#  ('黄日华', '翁美玲'),
#  ('周润发', '张国荣')]

# %%
import networkx as nx

# 创建 Graph
G = nx.Graph()
# 所有节点
nodes = []
# 所有边
edges = []
# 统计所有名字的组合
for comb in itertools.combinations(all_names, 2):
    # 两个演员合作过，才添加边
    if (comb[0], comb[1]) in has_cooperated_actors or (comb[1], comb[0]) in has_cooperated_actors:
        node1 = comb[0]
        node2 = comb[1]
        nodes.append(node1)
        nodes.append(node2)
        edges.append((node1, node2))
# 去除重复节点
nodes = list(set(nodes))
# 添加节点和边
G.add_nodes_from(nodes)
G.add_edges_from(edges)

# 节点对应到图上的坐标 (x, y)
pos = nx.spring_layout(G)

# %%
pos
# Out:
# {'章子怡': array([ 0.1036821 , -0.09094797]),
#  '张翰': array([ 0.62447267, -0.66774777]),
#  '江华': array([0.12572316, 0.33757467]),
#  '张柏芝': array([ 0.08458105, -0.05878481]),
#  '邱淑贞': array([ 0.02720898, -0.03744797]),
#  '陶大宇': array([0.04783227, 0.20615377]),
#  '黄杏秀': array([0.17060385, 0.4873489 ]),
#  '张涵予': array([ 0.16667687, -0.30885424]),
#  '朱茵': array([-0.14947316,  0.07683412]),
#  '张延': array([0.01857371, 0.29291456]),
#  '吴岱融': array([0.15971442, 0.09111466]),
#  '郑丹瑞': array([0.1087752 , 0.03079496]),
#  '刘嘉玲': array([0.02582046, 0.06793434]),
#  '林峯': array([0.19390422, 0.24186535]),
#  '莫文蔚': array([ 0.00405932, -0.00105833]),
#  '陈浩民': array([0.15390777, 0.31019878]),
#  '林倩萍': array([-0.24032241,  0.13641366]),
#  '温兆伦': array([-0.03584602,  0.16303195]),
#  '汤镇业': array([0.13857486, 0.38909676]),
#  '袁咏仪': array([-0.05820099,  0.01041767]),
#  '伍咏薇': array([0.10271908, 0.31999121]),
#  '陈秀雯': array([0.11365911, 0.07963025]),
#  '郑皓原': array([-0.37933873, -0.27255101]),
#  '赵薇': array([-0.11239867, -0.06309777]),
#  '浅野忠信': array([ 0.14553998, -0.16801548]),
#  '陈建斌': array([-0.23674769,  0.32271493]),
#  '张敏': array([-0.0938956 , -0.08908042]),
#  '巩俐': array([ 0.0007361, -0.1730602]),
#  '罗家英': array([-0.13272411, -0.00836669]),
#  '李影': array([-0.25298087, -0.04215153]),
#  '孙俪': array([-0.21526658,  0.34048831]),
#  '张国荣': array([ 0.05909322, -0.03078242]),
#  '刘筱筱': array([-0.34681068, -0.17716211]),
#  '秦岚': array([0.23229887, 0.35751489]),
#  '刘宇桥': array([ 0.16690384, -0.27588257]),
#  '周润发': array([ 0.04864505, -0.05643509]),
#  '周秀兰': array([0.13594205, 0.0088678 ]),
#  '张卫健': array([ 0.20754221, -0.25009851]),
#  '薛家燕': array([-0.00817583,  0.22160817]),
#  '卢巧音': array([ 0.19373712, -0.0683359 ]),
#  '陈奕迅': array([ 0.19088728, -0.09490138]),
#  '李立群': array([-0.365216 , -0.0663804]),
#  '刘丹': array([0.24421158, 0.19880446]),
#  '苗侨伟': array([0.1736081 , 0.16328524]),
#  '张智霖': array([-0.09126414,  0.14067178]),
#  '顾冠忠': array([0.28552242, 0.16540324]),
#  '钟汉良': array([-0.2712594, -0.0324705]),
#  '于小慧': array([-1.        , -0.27704674]),
#  '翁美玲': array([0.17165248, 0.18936885]),
#  '梁朝伟': array([0.06178992, 0.03044773]),
#  '樊少皇': array([0.17871386, 0.30115046]),
#  '陈道明': array([0.31781286, 0.41757057]),
#  '吴孟达': array([-0.05275429, -0.01660125]),
#  '乔宏': array([-0.22282867,  0.00891746]),
#  '金城武': array([-0.01298323,  0.04359836]),
#  '罗嘉良': array([-0.1231165 ,  0.16325803]),
#  '白凡': array([-0.97327556, -0.25358529]),
#  '郭可盈': array([-0.03245026,  0.24074514]),
#  '刘德华': array([-0.06208196, -0.04269215]),
#  '潘迎紫': array([0.28546629, 0.19301298]),
#  '钟楚红': array([ 0.09820919, -0.03314249]),
#  '尹扬明': array([0.14047275, 0.16248791]),
#  '陈汉玮': array([-0.25409963,  0.11327125]),
#  '姜武': array([ 0.05055616, -0.23731469]),
#  '严屹宽': array([ 0.58731919, -0.67196146]),
#  '周星驰': array([-0.04638069, -0.04787428]),
#  '张国立': array([ 0.1945287 , -0.38702443]),
#  '洪欣': array([-0.15861915,  0.15135446]),
#  '杨蕊': array([-0.37218221, -0.03903332]),
#  '吕良伟': array([ 0.1181897 , -0.18530489]),
#  '姜文': array([ 0.03837221, -0.17759929]),
#  '佘诗曼': array([0.09074729, 0.23946168]),
#  '萧芳芳': array([-0.15633766,  0.02551039]),
#  '富大龙': array([ 0.60561557, -0.63768829]),
#  '郑秀文': array([-0.18467925, -0.04560946]),
#  '何润东': array([0.29839883, 0.43775699]),
#  '赵雅芝': array([ 0.03376173, -0.10773735]),
#  '林青霞': array([ 0.02915367, -0.00870883]),
#  '葛优': array([ 0.0742407, -0.1605964]),
#  '张晓龙': array([-0.34053216, -0.11812983]),
#  '石修': array([0.17638216, 0.23518328]),
#  '任达华': array([0.08705199, 0.1202166 ]),
#  '林子祥': array([-0.15504508, -0.10119648]),
#  '沈傲君': array([ 0.20038994, -0.47915153]),
#  '屈菁菁': array([-0.40325456, -0.25838796]),
#  '张丰毅': array([ 0.02892682, -0.13113571]),
#  '黎明': array([-0.04013647,  0.05156395]),
#  '蔡少芬': array([-0.16119302,  0.25303141]),
#  '滕汝骏': array([ 0.0114    , -0.24792738]),
#  '蒋雯丽': array([ 0.17182766, -0.47896439]),
#  '陈百祥': array([-0.06265791, -0.15149242]),
#  '万梓良': array([ 0.15781431, -0.10478949]),
#  '黄日华': array([0.10924249, 0.22040531]),
#  '魏骏杰': array([-0.21438983,  0.04484669]),
#  '马精武': array([-0.0227264 , -0.28258608]),
#  '梁咏琪': array([-0.03034664,  0.07920403]),
#  '李幼斌': array([-0.93121245, -0.25634964]),
#  '何赛飞': array([-0.04748114, -0.26957554]),
#  '陈法蓉': array([ 0.23319665, -0.18977992]),
#  '杨盼盼': array([0.14336686, 0.4904965 ]),
#  '李嘉欣': array([-0.09907126,  0.05906556])}

# %%
from plotly.offline import init_notebook_mode, iplot
from plotly import graph_objs as go
# 绘制边的轨迹
edge_trace = go.Scatter(
    x=[],
    y=[],
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

# 遍历每一条边，根据上文获得的每一个节点的坐标，连接两个节点
for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_trace['x'] += tuple([x0, x1, None])
    edge_trace['y'] += tuple([y0, y1, None])

# 绘制点
node_trace = go.Scatter(
    x=[],
    y=[],
    text=[],
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        colorscale='YlGnBu',
        reversescale=True,
        color=[],
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line=dict(width=2)))

# 遍历每一个点
for node in G.nodes():
    x, y = pos[node]
    node_trace['x'] += tuple([x])
    node_trace['y'] += tuple([y])

# %%
# 遍历邻接列表，对应了 节点->一条边的另一个节点和权重
for node, adjacencies in enumerate(G.adjacency()):
    name = adjacencies[0]
    # 计算一个演员演过电影的平均得分
    works = [x for x in actors_data.values() if x['name'] == name][0]['works']
    avg_rate = sum([x['subject']['rating']['average']
                    for x in works])/len(works)
    # 每个节点的颜色
    node_trace['marker']['color'] += tuple([avg_rate])
    node_info = '{} {}'.format(name, avg_rate)
    # 每一个节点添加标注信息（名字, 平均评分）
    node_trace['text'] += tuple([node_info])

# %%
# 绘制图像
fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                title='<br>周星驰为中心的 100 个演员关系',
                titlefont=dict(size=16),
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20, l=5, r=5, t=40),
#                 annotations=[dict(
#                     text="周星驰为中心的 100 个演员关系",
#                     showarrow=False,
#                     xref="paper", yref="paper",
#                     x=0.005, y=-0.002)],
                xaxis=dict(showgrid=False, zeroline=False,
                           showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

iplot(fig, filename='周星驰为中心的 100 个演员关系')
# Out:
# <div>
#
#
#             <div id="6247ca7c-dd38-4fab-a165-793981671ac4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6247ca7c-dd38-4fab-a165-793981671ac4")) {
#                     Plotly.newPlot(
#                         '6247ca7c-dd38-4fab-a165-793981671ac4',
#                         [{"hoverinfo": "none", "line": {"color": "#888", "width": 0.5}, "mode": "lines", "type": "scatter", "x": [0.005602216564114401, 0.06272183218630127, null, 0.005602216564114401, -0.07152180188445283, null, 0.005602216564114401, -0.0493097503255068, null, 0.005602216564114401, 0.0016799254960966218, null, 0.9763884838776004, 0.9385529729137042, null, 0.9763884838776004, 0.9888420544789506, null, 0.03898228372057928, 0.05746286685413504, null, 0.03898228372057928, 0.05496063216933956, null, 0.03898228372057928, 0.030177986946837678, null, -0.22257649425076842, -0.13168573469626388, null, -0.22257649425076842, -0.1901408935872961, null, -0.22257649425076842, -0.11378220835844982, null, -0.22257649425076842, -0.3247115646332903, null, -0.22257649425076842, -0.314538564075176, null, -0.22257649425076842, -0.1485201034589763, null, -0.13168573469626388, -0.11378220835844982, null, -0.13168573469626388, -0.0493097503255068, null, -0.13168573469626388, -0.1485201034589763, null, -0.13168573469626388, -0.09901604281064434, null, 0.01556272718003254, 0.03436434720391629, null, 0.01556272718003254, -0.04844923030800895, null, 0.01556272718003254, 0.0795910914129362, null, 0.08802350650543761, 0.05746286685413504, null, 0.08802350650543761, 0.06153202128618142, null, -0.2212616901890052, -0.18327807974911484, null, -0.2212616901890052, -0.28823752003014885, null, -0.2212616901890052, -0.15433290535515481, null, -0.08528795578253973, -0.16909791758925055, null, -0.08528795578253973, 0.12448182076114919, null, -0.08528795578253973, -0.14531427640394892, null, -0.08528795578253973, 0.0027667657882976208, null, -0.08528795578253973, -0.14391748393536333, null, -0.08528795578253973, -0.1485201034589763, null, -0.08528795578253973, -0.11858271119667907, null, -0.08528795578253973, -0.18243123291658248, null, 0.03436434720391629, 0.0795910914129362, null, 0.05119691317215455, 0.10343677456279274, null, 0.05119691317215455, -0.0493097503255068, null, -0.13642560692545347, -0.11378220835844982, null, -0.13642560692545347, -0.1704664505099699, null, -0.07765750575737435, -0.06661311556752321, null, -0.07765750575737435, -0.18026456669946675, null, -0.07765750575737435, -0.11378220835844982, null, -0.07765750575737435, -0.07152180188445283, null, -0.07765750575737435, -0.0493097503255068, null, -0.07765750575737435, -0.14531427640394892, null, -0.07765750575737435, 0.030177986946837678, null, 0.1919378389290936, 0.10343677456279274, null, 0.1919378389290936, 0.18387767908375838, null, -0.1901408935872961, -0.11378220835844982, null, -0.1901408935872961, -0.14819853625327167, null, -0.1901408935872961, -0.1485201034589763, null, -0.1901408935872961, -0.23567078423624707, null, 0.0882572556386877, 0.10688351450872413, null, 0.0882572556386877, 0.030177986946837678, null, -0.16909791758925055, -0.14391748393536333, null, -0.06661311556752321, 0.0027667657882976208, null, -0.06661311556752321, -0.11858271119667907, null, -0.06661311556752321, 0.009916626631534448, null, -0.06661311556752321, -0.12228320251815772, null, -0.06661311556752321, -0.13218969545759673, null, -0.06661311556752321, 0.030177986946837678, null, 0.05746286685413504, 0.030177986946837678, null, 0.05746286685413504, 0.06153202128618142, null, -0.18026456669946675, -0.23876068525450952, null, -0.18026456669946675, -0.11378220835844982, null, -0.18026456669946675, -0.1485201034589763, null, -0.18026456669946675, -0.273807433858501, null, 0.05496063216933956, 0.030177986946837678, null, -0.04844923030800895, -0.11378220835844982, null, -0.04844923030800895, -0.0063219900344628115, null, -0.04844923030800895, -0.15446116785548974, null, -0.04844923030800895, 0.030177986946837678, null, 0.537063280101698, 0.45777939716556704, null, 0.537063280101698, 0.5390973841436596, null, -0.2146148643914063, -0.14531427640394892, null, -0.2146148643914063, -0.1485201034589763, null, 0.06272183218630127, 0.0016799254960966218, null, -0.18436643094455452, -0.15931013383222722, nu ...
